# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import re

# %%
df = pd.read_csv('easydinner_data.csv')

# %%
df.head()
# Out:
#                           NAME  RATING        ADDRESS       CITY  \
# 0                  Bella Aroma     4.6   Crowne Plaza  Ahmedabad
# 1  South Leaf - The Food Chain     4.4  Prahlad Nagar  Ahmedabad
# 2                      Essence     4.5   Crowne Plaza  Ahmedabad
# 3           The Chocolate Room     5.0  Prahlad Nagar  Ahmedabad
# 4                Sphere Lounge     4.2   Hotel Ramada  Ahmedabad
#
#                   DISHES APPROX_PRICE  DISCOUNTS
# 0                  Cafe.          700         55
# 1          South Indian.          900         40
# 2  Indian, North Indian.         2000         45
# 3                Bakery.          500         60
# 4   Indian, Continental.          900         35

# %%
df['AREA'] = df['AREA'].str.replace('\xa0 \| View All\(\d+\) Outlets', '', regex=True)

# %%
df
# Out:
#                                NAME  RATING                           AREA  \
# 0                    Bella Aroma4.6     4.6        Crowne Plaza, Ahmedabad
# 1    South Leaf - The Food Chain4.4     4.4  Prahlad Nagar, West Ahmedabad
# 2                        Essence4.5     4.5        Crowne Plaza, Ahmedabad
# 3             The Chocolate Room5.0     5.0  Prahlad Nagar, West Ahmedabad
# 4                  Sphere Lounge4.2     4.2        Hotel Ramada, Ahmedabad
# ..                              ...     ...                            ...
# 670                        Kanak4.5     4.5              Trident Hyderabad
# 671                      Connect1.0     1.0       Jubilee Hills, Hyderabad
# 672              The Library Bar4.0     4.0            The Leela Hyderabad
# 673                     Solcito 4.0     4.0            The Leela Hyderabad
# 674         The Foodstories Cafe4.0     4.0       Banjara Hills, Hyderabad
#
#                                                DISHES                  APPROX  \
# 0                           Cafe₹ 700 for two approx.   ₹ 700 for two approx.
# 1                   South Indian₹ 900 for two approx.   ₹ 900 for two approx.
# 2          Indian, North Indian₹ 2000 for two approx.  ₹ 2000 for two approx.
# 3                         Bakery₹ 500 for two approx.   ₹ 500 for two approx.
# 4            Indian, Continental₹ 900 for two approx.   ₹ 900 for two approx.
# ..                                                ...                     ...
# 670                      Indian₹ 4500 for two approx.  ₹ 4500 for two approx.
# 671                Multicuisine₹ 1200 for two approx.  ₹ 1200 for two approx.
# 672  Finger Food, Cocktail Menu₹ 3500 for two approx.  ₹ 3500 for two approx.
# 673                Multicuisine₹ 5000 for two approx.  ₹ 5000 for two approx.
# 674                    European₹ 1500 for two approx.  ₹ 1500 for two approx.
#
#                   DISC
# 0    30% Off + 25% Off
# 1    15% Off + 25% Off
# 2    20% Off + 25% Off
# 3    35% Off + 25% Off
# 4    10% Off + 25% Off
# ..                 ...
# 670  25% Off + 25% Off
# 671  15% Off + 25% Off
# 672   25% Off :Payeazy
# 673   25% Off :Payeazy
# 674   25% Off :Payeazy
#
# [675 rows x 6 columns]

# %%
df['DISHES'] = df['DISHES'].str.replace('\₹\s(\d*)\sfor two approx', '', regex=True)

# %%
df
# Out:
#                                NAME  RATING                           AREA  \
# 0                    Bella Aroma4.6     4.6        Crowne Plaza, Ahmedabad
# 1    South Leaf - The Food Chain4.4     4.4  Prahlad Nagar, West Ahmedabad
# 2                        Essence4.5     4.5        Crowne Plaza, Ahmedabad
# 3             The Chocolate Room5.0     5.0  Prahlad Nagar, West Ahmedabad
# 4                  Sphere Lounge4.2     4.2        Hotel Ramada, Ahmedabad
# ..                              ...     ...                            ...
# 670                        Kanak4.5     4.5              Trident Hyderabad
# 671                      Connect1.0     1.0       Jubilee Hills, Hyderabad
# 672              The Library Bar4.0     4.0            The Leela Hyderabad
# 673                     Solcito 4.0     4.0            The Leela Hyderabad
# 674         The Foodstories Cafe4.0     4.0       Banjara Hills, Hyderabad
#
#                           DISHES                  APPROX               DISC
# 0                          Cafe.   ₹ 700 for two approx.  30% Off + 25% Off
# 1                  South Indian.   ₹ 900 for two approx.  15% Off + 25% Off
# 2          Indian, North Indian.  ₹ 2000 for two approx.  20% Off + 25% Off
# 3                        Bakery.   ₹ 500 for two approx.  35% Off + 25% Off
# 4           Indian, Continental.   ₹ 900 for two approx.  10% Off + 25% Off
# ..                           ...                     ...                ...
# 670                      Indian.  ₹ 4500 for two approx.  25% Off + 25% Off
# 671                Multicuisine.  ₹ 1200 for two approx.  15% Off + 25% Off
# 672  Finger Food, Cocktail Menu.  ₹ 3500 for two approx.   25% Off :Payeazy
# 673                Multicuisine.  ₹ 5000 for two approx.   25% Off :Payeazy
# 674                    European.  ₹ 1500 for two approx.   25% Off :Payeazy
#
# [675 rows x 6 columns]

# %%
df['APPROX'] = df['APPROX'].str.replace('\D', '', regex=True)

# %%
df
# Out:
#                                NAME  RATING                           AREA  \
# 0                    Bella Aroma4.6     4.6        Crowne Plaza, Ahmedabad
# 1    South Leaf - The Food Chain4.4     4.4  Prahlad Nagar, West Ahmedabad
# 2                        Essence4.5     4.5        Crowne Plaza, Ahmedabad
# 3             The Chocolate Room5.0     5.0  Prahlad Nagar, West Ahmedabad
# 4                  Sphere Lounge4.2     4.2        Hotel Ramada, Ahmedabad
# ..                              ...     ...                            ...
# 670                        Kanak4.5     4.5              Trident Hyderabad
# 671                      Connect1.0     1.0       Jubilee Hills, Hyderabad
# 672              The Library Bar4.0     4.0            The Leela Hyderabad
# 673                     Solcito 4.0     4.0            The Leela Hyderabad
# 674         The Foodstories Cafe4.0     4.0       Banjara Hills, Hyderabad
#
#                           DISHES APPROX               DISC
# 0                          Cafe.    700  30% Off + 25% Off
# 1                  South Indian.    900  15% Off + 25% Off
# 2          Indian, North Indian.   2000  20% Off + 25% Off
# 3                        Bakery.    500  35% Off + 25% Off
# 4           Indian, Continental.    900  10% Off + 25% Off
# ..                           ...    ...                ...
# 670                      Indian.   4500  25% Off + 25% Off
# 671                Multicuisine.   1200  15% Off + 25% Off
# 672  Finger Food, Cocktail Menu.   3500   25% Off :Payeazy
# 673                Multicuisine.   5000   25% Off :Payeazy
# 674                    European.   1500   25% Off :Payeazy
#
# [675 rows x 6 columns]

# %%
def extract_discounts(offer):
    return re.findall(r'(\d+)%', str(offer))

df['DISCOUNTS'] = df['DISC'].apply(extract_discounts)
df['DISCOUNTS'].apply(pd.Series)
# Out:
#       0    1
# 0    30   25
# 1    15   25
# 2    20   25
# 3    35   25
# 4    10   25
# ..   ..  ...
# 670  25   25
# 671  15   25
# 672  25  NaN
# 673  25  NaN
# 674  25  NaN
#
# [675 rows x 2 columns]

# %%
df['DISCOUNTS'] = df['DISCOUNTS'].apply(lambda x: sum(map(int, x)) if isinstance(x, list) else 0)
df['DISCOUNTS'].head()
# Out:
# 0    55
# 1    40
# 2    45
# 3    60
# 4    35
# Name: DISCOUNTS, dtype: int64

# %%
df.isnull().sum()
# Out:
# NAME         0
# RATING       0
# AREA         0
# DISHES       0
# APPROX       0
# DISC         0
# DISCOUNTS    0
# dtype: int64

# %%
df
# Out:
#                                NAME  RATING                           AREA  \
# 0                    Bella Aroma4.6     4.6        Crowne Plaza, Ahmedabad
# 1    South Leaf - The Food Chain4.4     4.4  Prahlad Nagar, West Ahmedabad
# 2                        Essence4.5     4.5        Crowne Plaza, Ahmedabad
# 3             The Chocolate Room5.0     5.0  Prahlad Nagar, West Ahmedabad
# 4                  Sphere Lounge4.2     4.2        Hotel Ramada, Ahmedabad
# ..                              ...     ...                            ...
# 670                        Kanak4.5     4.5              Trident Hyderabad
# 671                      Connect1.0     1.0       Jubilee Hills, Hyderabad
# 672              The Library Bar4.0     4.0            The Leela Hyderabad
# 673                     Solcito 4.0     4.0            The Leela Hyderabad
# 674         The Foodstories Cafe4.0     4.0       Banjara Hills, Hyderabad
#
#                           DISHES APPROX               DISC  DISCOUNTS
# 0                          Cafe.    700  30% Off + 25% Off         55
# 1                  South Indian.    900  15% Off + 25% Off         40
# 2          Indian, North Indian.   2000  20% Off + 25% Off         45
# 3                        Bakery.    500  35% Off + 25% Off         60
# 4           Indian, Continental.    900  10% Off + 25% Off         35
# ..                           ...    ...                ...        ...
# 670                      Indian.   4500  25% Off + 25% Off         50
# 671                Multicuisine.   1200  15% Off + 25% Off         40
# 672  Finger Food, Cocktail Menu.   3500   25% Off :Payeazy         25
# 673                Multicuisine.   5000   25% Off :Payeazy         25
# 674                    European.   1500   25% Off :Payeazy         25
#
# [675 rows x 7 columns]

# %%
# df = df.drop(columns=['Discounts'])

# %%
df
# Out:
#                                NAME  RATING                           AREA  \
# 0                    Bella Aroma4.6     4.6        Crowne Plaza, Ahmedabad
# 1    South Leaf - The Food Chain4.4     4.4  Prahlad Nagar, West Ahmedabad
# 2                        Essence4.5     4.5        Crowne Plaza, Ahmedabad
# 3             The Chocolate Room5.0     5.0  Prahlad Nagar, West Ahmedabad
# 4                  Sphere Lounge4.2     4.2        Hotel Ramada, Ahmedabad
# ..                              ...     ...                            ...
# 670                        Kanak4.5     4.5              Trident Hyderabad
# 671                      Connect1.0     1.0       Jubilee Hills, Hyderabad
# 672              The Library Bar4.0     4.0            The Leela Hyderabad
# 673                     Solcito 4.0     4.0            The Leela Hyderabad
# 674         The Foodstories Cafe4.0     4.0       Banjara Hills, Hyderabad
#
#                           DISHES APPROX               DISC  DISCOUNTS
# 0                          Cafe.    700  30% Off + 25% Off         55
# 1                  South Indian.    900  15% Off + 25% Off         40
# 2          Indian, North Indian.   2000  20% Off + 25% Off         45
# 3                        Bakery.    500  35% Off + 25% Off         60
# 4           Indian, Continental.    900  10% Off + 25% Off         35
# ..                           ...    ...                ...        ...
# 670                      Indian.   4500  25% Off + 25% Off         50
# 671                Multicuisine.   1200  15% Off + 25% Off         40
# 672  Finger Food, Cocktail Menu.   3500   25% Off :Payeazy         25
# 673                Multicuisine.   5000   25% Off :Payeazy         25
# 674                    European.   1500   25% Off :Payeazy         25
#
# [675 rows x 7 columns]

# %%
df['NAME'] = df['NAME'].str[:-3]

# %%
df
# Out:
#                             NAME  RATING                           AREA  \
# 0                    Bella Aroma     4.6        Crowne Plaza, Ahmedabad
# 1    South Leaf - The Food Chain     4.4  Prahlad Nagar, West Ahmedabad
# 2                        Essence     4.5        Crowne Plaza, Ahmedabad
# 3             The Chocolate Room     5.0  Prahlad Nagar, West Ahmedabad
# 4                  Sphere Lounge     4.2        Hotel Ramada, Ahmedabad
# ..                           ...     ...                            ...
# 670                        Kanak     4.5              Trident Hyderabad
# 671                      Connect     1.0       Jubilee Hills, Hyderabad
# 672              The Library Bar     4.0            The Leela Hyderabad
# 673                     Solcito      4.0            The Leela Hyderabad
# 674         The Foodstories Cafe     4.0       Banjara Hills, Hyderabad
#
#                           DISHES APPROX               DISC  DISCOUNTS
# 0                          Cafe.    700  30% Off + 25% Off         55
# 1                  South Indian.    900  15% Off + 25% Off         40
# 2          Indian, North Indian.   2000  20% Off + 25% Off         45
# 3                        Bakery.    500  35% Off + 25% Off         60
# 4           Indian, Continental.    900  10% Off + 25% Off         35
# ..                           ...    ...                ...        ...
# 670                      Indian.   4500  25% Off + 25% Off         50
# 671                Multicuisine.   1200  15% Off + 25% Off         40
# 672  Finger Food, Cocktail Menu.   3500   25% Off :Payeazy         25
# 673                Multicuisine.   5000   25% Off :Payeazy         25
# 674                    European.   1500   25% Off :Payeazy         25
#
# [675 rows x 7 columns]

# %%
locations = ['Ahmedabad', 'Mumbai', 'Pune', 'Bengaluru','Hyderabad']
loc = np.repeat(locations, 135)
df['LOCATION'] = loc

# %%
df.iloc[:137,:]
# Out:
#                                     NAME  RATING  \
# 0                            Bella Aroma     4.6
# 1            South Leaf - The Food Chain     4.4
# 2                                Essence     4.5
# 3                     The Chocolate Room     5.0
# 4                          Sphere Lounge     4.2
# ..                                   ...     ...
# 132                               Pol 21     4.2
# 133                              Sankalp     4.3
# 134  Beeji Punjabi Restaurant & Banquets     5.0
# 135                           Cray Craft     4.4
# 136                             Kitty Su     2.3
#
#                               AREA                                    DISHES  \
# 0          Crowne Plaza, Ahmedabad                                     Cafe.
# 1    Prahlad Nagar, West Ahmedabad                             South Indian.
# 2          Crowne Plaza, Ahmedabad                     Indian, North Indian.
# 3    Prahlad Nagar, West Ahmedabad                                   Bakery.
# 4          Hotel Ramada, Ahmedabad                      Indian, Continental.
# ..                             ...                                       ...
# 132        Thaltej, West Ahmedabad                          Chinese, Indian.
# 133           Sola, West Ahmedabad                             South Indian.
# 134         Naroda, East Ahmedabad                      North Indian, Asian.
# 135  Andheri East, Western Suburbs                          Chinese, Indian.
# 136              The Lalit, Mumbai  Drinks Only, Finger Food, Cocktail Menu.
#
#     APPROX               DISC  DISCOUNTS   LOCATION
# 0      700  30% Off + 25% Off         55  Ahmedabad
# 1      900  15% Off + 25% Off         40  Ahmedabad
# 2     2000  20% Off + 25% Off         45  Ahmedabad
# 3      500  35% Off + 25% Off         60  Ahmedabad
# 4      900  10% Off + 25% Off         35  Ahmedabad
# ..     ...                ...        ...        ...
# 132   1200  50% Off + 25% Off         75  Ahmedabad
# 133    600  15% Off + 25% Off         40  Ahmedabad
# 134   1000  25% Off + 25% Off         50  Ahmedabad
# 135   2000            25% Off         25     Mumbai
# 136   2000            25% Off         25     Mumbai
#
# [137 rows x 8 columns]

# %%
df[['AREA', 'City']] = df['AREA'].str.split(',', n=1, expand=True)

df = df.drop(columns=['City'])

# %%
df
# Out:
#                             NAME  RATING                 AREA  \
# 0                    Bella Aroma     4.6         Crowne Plaza
# 1    South Leaf - The Food Chain     4.4        Prahlad Nagar
# 2                        Essence     4.5         Crowne Plaza
# 3             The Chocolate Room     5.0        Prahlad Nagar
# 4                  Sphere Lounge     4.2         Hotel Ramada
# ..                           ...     ...                  ...
# 670                        Kanak     4.5    Trident Hyderabad
# 671                      Connect     1.0        Jubilee Hills
# 672              The Library Bar     4.0  The Leela Hyderabad
# 673                     Solcito      4.0  The Leela Hyderabad
# 674         The Foodstories Cafe     4.0        Banjara Hills
#
#                           DISHES APPROX               DISC  DISCOUNTS  \
# 0                          Cafe.    700  30% Off + 25% Off         55
# 1                  South Indian.    900  15% Off + 25% Off         40
# 2          Indian, North Indian.   2000  20% Off + 25% Off         45
# 3                        Bakery.    500  35% Off + 25% Off         60
# 4           Indian, Continental.    900  10% Off + 25% Off         35
# ..                           ...    ...                ...        ...
# 670                      Indian.   4500  25% Off + 25% Off         50
# 671                Multicuisine.   1200  15% Off + 25% Off         40
# 672  Finger Food, Cocktail Menu.   3500   25% Off :Payeazy         25
# 673                Multicuisine.   5000   25% Off :Payeazy         25
# 674                    European.   1500   25% Off :Payeazy         25
#
#       LOCATION
# 0    Ahmedabad
# 1    Ahmedabad
# 2    Ahmedabad
# 3    Ahmedabad
# 4    Ahmedabad
# ..         ...
# 670  Hyderabad
# 671  Hyderabad
# 672  Hyderabad
# 673  Hyderabad
# 674  Hyderabad
#
# [675 rows x 8 columns]

# %%
df = df.rename(columns={'AREA':'ADDRESS', 'APPROX':'APPROX_PRICE','LOCATION':'CITY'})

# %%
final_cols = [
    'NAME',
    'RATING',
    'ADDRESS', 
    'CITY', 
    'DISHES', 
    'APPROX_PRICE', 
    'DISCOUNTS'
]
df = df[final_cols]

# %%
df.isnull().sum()
# Out:
# NAME            0
# RATING          0
# ADDRESS         0
# CITY            0
# DISHES          0
# APPROX_PRICE    0
# DISCOUNTS       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (675, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NAME          675 non-null    object
#  1   RATING        675 non-null    float64
#  2   ADDRESS       675 non-null    object
#  3   CITY          675 non-null    object
#  4   DISHES        675 non-null    object
#  5   APPROX_PRICE  675 non-null    object
#  6   DISCOUNTS     675 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 37.0+ KB

# %%
df.to_csv('ED_cleandata.csv', index=False)
